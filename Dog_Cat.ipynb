# %%
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import cv2

# %%
pil_im = Image.open('original_image.jpg')
pil_im
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=978x978>

# %%
image= cv2.imread('original_image.jpg')
plt.imshow(image)
# cv2.imshow('image',image)
# cv2.waitkey(0)
# cv2.destroyAllwindows()

# %%
resize = cv2.resize(image,(100,200))
#cv2.imshow('resize',resize)
#cv2.waitkey(0)
#cv2.destroyAllwindows()

# %%
plt.imshow(resize)

# %%
pil_im_grey=Image.open('original_image.jpg').convert('L')
resize = pil_im.resize((128,128))
resize
pil_im_grey
# Out:
# <PIL.Image.Image image mode=L size=978x978>

# %%
edges=cv2.Canny(image,100,200)
plt.imshow(edges)

# %%
Gaussian = cv2.GaussianBlur(image,(7,7),0)
plt.imshow(Gaussian)
